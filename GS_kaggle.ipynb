# %%
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
#!rm -rf gaussian-splatting
# !ls /kaggle/working/gaussian-splatting/submodules
# !readlink -f submodules
# Out:
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 7.73 MiB/s, done.
# Resolving deltas: 100% (346/346), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/kaggle/working/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# !pip install -q plyfile

#%cd /kaggle/working/gaussian-splatting
# !pip install -q /kaggle/working/gaussian-splatting/submodules/diff-gaussian-rasterization
#!pip install -q /kaggle/working/gaussian-splatting/submodules/simple-knn #NOT working, is on gitlab

#!wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
#!unzip tandt_db.zip
#readlink -f tandt_db
# !git clone https://gitlab.inria.fr/bkerbl/simple-knn.git

# !pip install -q /kaggle/working/simple-knn
#!readlink -f simple-knn
#%cd /kaggle/working/gaussian-splatting/simple-knn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Cloning into 'simple-knn'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 37 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 9.46 KiB | 9.46 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !cp -r /kaggle/input/datasets/leonardochist/pinholebike/ /kaggle/working/

# !mkdir /kaggle/working/output

# %%
# !python /kaggle/working/gaussian-splatting/train.py -s /kaggle/working/pinholebike/pinhole_bike -m /kaggle/working/output -r 2
# !ls
# Out:
# 2026-07-21 13:01:36.936860: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1784638897.156918     481 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1784638897.213285     481 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1784638897.722926     481 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#15.6 GB max during training
# !zip -r output.zip /kaggle/working/output
# Out:
#   adding: kaggle/working/output/ (stored 0%)
#   adding: kaggle/working/output/cfg_args (deflated 32%)
#   adding: kaggle/working/output/input.ply (deflated 45%)
#   adding: kaggle/working/output/point_cloud/ (stored 0%)
#   adding: kaggle/working/output/point_cloud/iteration_7000/ (stored 0%)
#   adding: kaggle/working/output/point_cloud/iteration_7000/point_cloud.ply (deflated 16%)
#   adding: kaggle/working/output/point_cloud/iteration_30000/ (stored 0%)
#   adding: kaggle/working/output/point_cloud/iteration_30000/point_cloud.ply (deflated 14%)
#   adding: kaggle/working/output/cameras.json (deflated 68%)
#   adding: kaggle/working/output/events.out.tfevents.1784638918.61412b6f2aa1.481.0 (deflated 13%)

# %%
from IPython.display import FileLink
# Do not include '/kaggle/working/' in the string path, just the filename
FileLink("/kaggle/working/output.zip")
# Out:
# /kaggle/working/output.zip

# %%
# Out:
# cp: cannot create regular file '/kaggle/input/datasets/leonardochist/output.zip': Read-only file system
